# %% [markdown]
# <a href="https://colab.research.google.com/github/Sammydcode/vectorization-benchmark/blob/main/vectorization_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time

a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized version: " + str(1000*(toc-tic)) + "ms")

c= 0
tic = time.time()
for i in range(1000000):
    c += a[i]*b[i]
toc = time.time()

print(c)
print("For loop: " + str(1000*(toc-tic)) + "ms")
# Out:
# 250049.73349944537
# Vectorized version: 1.5511512756347656ms
# 250049.7334994395
# For loop: 999.4196891784668ms
